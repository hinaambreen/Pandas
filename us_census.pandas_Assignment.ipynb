# %%
import pandas as pd
from glob import glob
files=glob('states*')
us_census=pd.concat((pd.read_csv(file)for file in files), ignore_index=True)
us_census
# Out:
#     Unnamed: 0                 State  TotalPop             Hispanic  \
# 0            0               Alabama   4830620  3.7516156462584975%
# 1            1                Alaska    733375   5.909580838323351%
# 2            2               Arizona   6641928  29.565921052631502%
# 3            3              Arkansas   2958208   6.215474452554738%
# 4            4            California  38421464  37.291874687968054%
# 5            5              Colorado   5278906   20.78438003220608%
# 6            0              Colorado   5278906   20.78438003220608%
# 7            1           Connecticut   3593222  15.604830917874388%
# 8            2              Delaware    926454    8.82476635514019%
# 9            3  District of Columbia    647484   9.165921787709499%
# 10           4               Florida  19645772    21.3385426653884%
# 11           5               Georgia  10006693   8.418242207460397%
# 12           0               Georgia  10006693   8.418242207460397%
# ...

# %%
#import pandas as pd 
#a = pd.read_csv("states0.csv")
#b = pd.read_csv("states1.csv")
#c = pd.read_csv("states2.csv")
#d = pd.read_csv("states3.csv")
#e = pd.read_csv("states4.csv")
#f = pd.read_csv("states5.csv")
#g = pd.read_csv("states6.csv")
#h = pd.read_csv("states7.csv")
#i = pd.read_csv("states8.csv")
#j = pd.read_csv("states9.csv")

# %%
#to concatenate csv files
#import pandas as pd
#import numpy as np
#us_census = pd.concat([a,b,c,d,e,f,g,h,i,j])
#us_census.index=np.arange(60)
#us_census

# %%
#to make a DataFrame of csv files
#us_census = pd.DataFrame(us_census)

# %%
us_census.head()
# Out:
#    Unnamed: 0       State  TotalPop             Hispanic                White  \
# 0           0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1           1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2           2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3           3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4           4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific              Income            GenderPop
# ...

# %%
us_census.columns
# Out:
# Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#        'Native', 'Asian', 'Pacific', 'Income', 'GenderPop'],
#       dtype='object')

# %%
us_census.dtypes
# Out:
# Unnamed: 0     int64
# State         object
# TotalPop       int64
# Hispanic      object
# White         object
# Black         object
# Native        object
# Asian         object
# Pacific       object
# Income        object
# GenderPop     object
# dtype: object

# %%
us_census["Income"]=us_census["Income"].replace("\$","",regex=True)
us_census["Income"]=us_census["Income"].astype("float")
us_census["Income"]
# Out:
# 0     43296.358603
# 1     70354.743902
# 2     54207.820955
# 3     41935.633968
# 4     67264.782303
# 5     64657.801787
# 6     64657.801787
# 7     76146.560588
# 8     61827.976636
# 9     75466.363636
# 10    50690.194987
# 11    50811.082051
# 12    50811.082051
# 13    73264.426282
# 14    48017.315436
# 15    59587.048875
# 16    48616.227848
# 17    53017.753041
# 18    53017.753041
# 19    53885.612648
# 20    45285.802536
# 21    44957.993761
# 22    49181.974359
# 23    78765.400725
# 24    78765.400725
# 25    72838.936726
# 26    51201.830037
# 27    62820.833959
# 28    38909.919207
# 29    49763.987726
# 30    49763.987726
# 31    47645.682836
# 32    55916.469697
# 33    55526.525074
# 34    68728.859589
# 35    76581.083417
# 36    76581.083417
# 37    47329.967871
# 38    64290.749113
# 39    49937.464137
# 40    58188.112195
# 41    49655.248466
# 42    49655.248466
# 43    48100.854267
# 44    54271.901818
# 45    56170.464510
# 46    20720.538286
# ...

# %%
#avg_income= us_census.Income.str.replace("$","").astype(float,errors="raise")

# %%
us_census[["Men","Women"]]=us_census.GenderPop.str.split("_",expand=True)
us_census.Men
us_census.Women
# Out:
# 0      2489527F
# 1       349215F
# 2      3342840F
# 3      1506295F
# 4     19334329F
# 5      2630239F
# 6      2630239F
# 7      1841615F
# 8       478041F
# 9       340810F
# 10    10045763F
# 11     5123362F
# 12     5123362F
# 13      696428F
# 14      806083F
# 15     6556862F
# 16     3333382F
# 17     1558931F
# 18     1558931F
# 19     1453125F
# 20     2233145F
# 21     2364097F
# 22      679019F
# 23            F
# 24            F
# 25     3455936F
# 26     5038598F
# 27     2727005F
# 28     1536358F
# 29     3081445F
# 30     3081445F
# 31            F
# 32      939759F
# 33     1390901F
# 34      670717F
# 35     4561386F
# 36     4561386F
# 37     1051703F
# 38    10131373F
# 39     5049925F
# 40      353677F
# 41     5913084F
# 42     5913084F
# 43     1942789F
# 44     1990780F
# 45     6534215F
# 46     1869213F
# 47      543273F
# 48      543273F
# 49     2455167F
# 50      419713F
# 51     3331859F
# 52    13367298F
# 53     1444150F
# 54     1444150F
# ...

# %%
us_census.Men.replace('(M)','',regex=True, inplace = True)
us_census.Women.replace('(F)','',regex=True, inplace = True)
us_census["Men"] = pd.to_numeric(us_census["Men"]).astype(float)
us_census["Women"]=pd.to_numeric(us_census["Women"]).astype(float)
us_census["Women"].dtypes
# Out:
# dtype('float64')

# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.scatter(us_census.Women,income_column)
plt.xlabel("income")
plt.ylabel("female")
plt.show()

# %%
us_census["Women"][us_census["Women"].isnull()]
f_pop=us_census["TotalPop"]-us_census["Men"]
f_pop.dtypes
us_census["Women"]=us_census["Women"].fillna(f_pop)
#us_census["Women"].replace(np.nan,f_Pop,inplace=True)
us_census["Women"]
# Out:
# 0      2489527.0
# 1       349215.0
# 2      3342840.0
# 3      1506295.0
# 4     19334329.0
# 5      2630239.0
# 6      2630239.0
# 7      1841615.0
# 8       478041.0
# 9       340810.0
# 10    10045763.0
# 11     5123362.0
# 12     5123362.0
# 13      696428.0
# 14      806083.0
# 15     6556862.0
# 16     3333382.0
# 17     1558931.0
# 18     1558931.0
# 19     1453125.0
# 20     2233145.0
# 21     2364097.0
# 22      679019.0
# 23     3057895.0
# 24     3057895.0
# 25     3455936.0
# 26     5038598.0
# 27     2727005.0
# 28     1536358.0
# 29     3081445.0
# 30     3081445.0
# 31      504536.0
# 32      939759.0
# 33     1390901.0
# 34      670717.0
# 35     4561386.0
# 36     4561386.0
# 37     1051703.0
# 38    10131373.0
# 39     5049925.0
# 40      353677.0
# 41     5913084.0
# 42     5913084.0
# 43     1942789.0
# 44     1990780.0
# 45     6534215.0
# 46     1869213.0
# 47      543273.0
# 48      543273.0
# 49     2455167.0
# 50      419713.0
# 51     3331859.0
# ...

# %%
us_census.duplicated()
us_census.drop_duplicates(inplace=True)
us_census.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# dtype: bool

# %%
import matplotlib.pyplot as plt
plt.scatter(us_census.Women,us_census["Income"])
plt.xlabel("income")
plt.ylabel("female")
plt.show()

# %%
us_census.isnull()
us_census=us_census.fillna(method="ffill")
us_census.isnull()
#us_census
# Out:
#     Unnamed: 0  State  TotalPop  Hispanic  White  Black  Native  Asian  \
# 0        False  False     False     False  False  False   False  False
# 1        False  False     False     False  False  False   False  False
# 2        False  False     False     False  False  False   False  False
# 3        False  False     False     False  False  False   False  False
# 4        False  False     False     False  False  False   False  False
# 5        False  False     False     False  False  False   False  False
# 6        False  False     False     False  False  False   False  False
# 7        False  False     False     False  False  False   False  False
# 8        False  False     False     False  False  False   False  False
# 9        False  False     False     False  False  False   False  False
# 10       False  False     False     False  False  False   False  False
# 11       False  False     False     False  False  False   False  False
# ...

# %%
us_census=us_census.drop(["GenderPop","Unnamed: 0"], axis=1)

# %%
us_census.columns
# Out:
# Index(['State', 'TotalPop', 'Hispanic', 'White', 'Black', 'Native', 'Asian',
#        'Pacific', 'Income', 'Men', 'Women'],
#       dtype='object')

# %%
us_census.replace('(%)','',regex=True, inplace = True)
us_census
us_census2=us_census.iloc[:,1:].apply(pd.to_numeric).astype(float)
us_census2.dtypes
# Out:
# TotalPop    float64
# Hispanic    float64
# White       float64
# Black       float64
# Native      float64
# Asian       float64
# Pacific     float64
# Income      float64
# Men         float64
# Women       float64
# dtype: object

# %%
plt.hist(us_census2.TotalPop,rwidth=0.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.hist(us_census2.Hispanic,rwidth=0.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.hist(us_census2.Asian,rwidth=0.5)
plt.show
plt.hist(us_census2.Pacific,rwidth=0.9)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.hist(us_census2.Black,rwidth=0.5)
plt.show
plt.hist(us_census2.Native,rwidth=0.9)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.hist(us_census2.Black,rwidth=0.5)
plt.show
plt.hist(us_census2.Native,rwidth=0.5)
plt.show
plt.hist(us_census2.Asian,rwidth=0.5)
plt.show
plt.hist(us_census2.Hispanic,rwidth=0.5)
plt.show
plt.hist(us_census2.White,rwidth=0.5)
plt.show
plt.hist(us_census2.Pacific,rwidth=0.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
us_census2.columns
# Out:
# Index(['TotalPop', 'Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific',
#        'Income', 'Men', 'Women'],
#       dtype='object')

# %%
plt.plot(us_census2.Pacific)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(us_census2.Women)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt. plot(us_census.Men)

# %%
plt.plot(us_census.Women,us_census.Income)

# %%
#plt.subplot(us_census[:],us_census.loc["3,Men"])
#plt.imshow
plt.figure(); us_census.plot(style='k--', label='Series'); plt.legend()

# %%
plt.plot(us_census.TotalPop, "g")
plt.plot(us_census.Women, "r")

# %%
us_census2.columns
# Out:
# Index(['TotalPop', 'Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific',
#        'Income', 'Men', 'Women'],
#       dtype='object')
